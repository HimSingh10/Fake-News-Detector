# %%
import pandas as pd

pred = model.predict(X_test)
print(pd.Series(pred).value_counts())
# Out:
# 1    637
# 0    630
# Name: count, dtype: int64

# %%
import pandas as pd
import re
import nltk
import pickle
import os

from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

print("Starting...")

# Download stopwords
nltk.download('stopwords')

# Load dataset
data = pd.read_csv("fake_or_real_news.csv")
print("Dataset loaded")

# Convert labels
data["label"] = data["label"].map({"FAKE": 0, "REAL": 1})

# Drop nulls
data = data.dropna()
print("Data cleaned")

# Stopwords
stop_words = set(stopwords.words('english'))

# Clean text
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return " ".join(words)

data["text"] = data["text"].apply(clean_text)
print("Text processed")

# TF-IDF
vectorizer = TfidfVectorizer(max_features=5000)
X = vectorizer.fit_transform(data["text"])
y = data["label"]
print("Vectorization done")

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = LinearSVC(class_weight='balanced')
model.fit(X_train, y_train)
print("Model trained")

# Accuracy
pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, pred))

# SAVE FILES (IMPORTANT)
pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

print("Files saved in:", os.getcwd())
print("Files now:", os.listdir())
# Out:
# Starting...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\himan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Dataset loaded
# Data cleaned
# Text processed
# Vectorization done
# Model trained
# Accuracy: 0.9273875295974744
# Files saved in: d:\End to End ML Project\Fake News Detection
# Files now: ['app.py', 'fake_or_real_news.csv', 'model.ipynb', 'model.pkl', 'rea', 'Readme.md', 'requirements.txt', 'vectorizer.pkl', 'venv']

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: click in c:\users\himan\anaconda3\envs\emotion_env\lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\himan\anaconda3\envs\emotion_env\lib\site-packages (from nltk) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\himan\anaconda3\envs\emotion_env\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl (278 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, nltk
#
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ---------------------------------------- 0/3 [tqdm]
#    ------------- -------------------------- 1/3 [regex]
#    ------------- -------------------------- 1/3 [regex]
#    ------------- -------------------------- 1/3 [regex]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed nltk-3.9.4 regex-2026.4.4 tqdm-4.67.3

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\himan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import os
print(os.getcwd())
# Out:
# d:\End to End ML Project\Fake News Detection

# %%
os.listdir()
# Out:
# ['app.py',
#  'fake_or_real_news.csv',
#  'model.ipynb',
#  'model.pkl',
#  'rea',
#  'Readme.md',
#  'requirements.txt',
#  'vectorizer.pkl',
#  'venv']

# %%
import pickle
import os

# Save in current directory explicitly
pickle.dump(model, open("model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

print("Saved at:", os.getcwd())
# Out:
# Saved at: d:\End to End ML Project\Fake News Detection
